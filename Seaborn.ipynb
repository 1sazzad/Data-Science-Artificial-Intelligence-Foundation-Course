# %% [markdown]
# <a href="https://colab.research.google.com/github/1sazzad/Data-Science-Artificial-Intelligence-Foundation-Course/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **What is Seaborn?**
# Seaborn is a Python data visualization library built on top of Matplotlib.
#
# **Why Data Scientists Love Seaborn**
# ✅Works directly with Pandas DataFrames
# ✅ Has beautiful default styles
# ✅ Built-in statistical plots
# ✅ Less code than Matplotlib
# ✅ Great for EDA (Exploratory Data Analysis)
# **Install Seaborn**
# ```
# pip install seaborn
# ```
# **If you are using colab use ! after pip**
#
# **Import:**
# ```
# import seaborn as sns
# ```

# %%
# Example

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)

plt.show()

# %% [markdown]
# **Built-in Dataset (Very Useful)**
# ```
# sns.get_dataset_names()
# ```
# | Dataset  | Description             |
# | -------- | ----------------------- |
# | tips     | Restaurant tips dataset |
# | titanic  | Titanic passengers      |
# | iris     | Flower dataset          |
# | flights  | Airline passengers      |
# | diamonds | Diamond prices          |

# %%
# example
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # **The Main Types of Seaborn Plots**
# Think of Seaborn plots in 4 main categories.
# | Category           | Purpose                      |
# | ------------------ | ---------------------------- |
# | Distribution plots | Understand data distribution |
# | Relationship plots | Relation between variables   |
# | Categorical plots  | Compare categories           |
# | Matrix plots       | Correlation / heatmaps       |

# %% [markdown]
# ## **Distribution plots**
# `histplot()` `kdeplot()` `displot()` `ecdfplot()` `rugplot()`

# %% [markdown]
# ### **Histogram - `histplot()`**
# A histogram divides data into bins and counts frequency.
# $$
# \text{frequency} = \text{count}(x_i \in \text{bin}_j)
# $$

# %%
# Histplot()

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.histplot(tips["total_bill"])

plt.show()

# %%
# Control Number of Bins
sns.histplot(tips["total_bill"], bins=30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Add KDE Curve
sns.histplot(tips["total_bill"], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### **KDE Plot (Kernel Density Estimation)**
# Histogram is discreat.
# KDE estimates **continuous probability density**
# Formula:
# $$
# f(x) = \frac{1}{nh} \sum_{i=1}^{n} K\left(\frac{x - x_i}{h}\right)
# $$
# Where:
# * K = kernel function
# * h = bandwidth
# * n = observations

# %%
sns.kdeplot(tips["total_bill"])
plt.show()

# %%
# Multiple Groups
sns.kdeplot(data=tips, x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### **Displot (Figure Level)**
# `displot()` is a high-level distribution function. It can automatically create multiple distribution plots.

# %%
sns.displot(tips["total_bill"], kde=True)

# %%
# By Category
sns.displot(data=tips, x="total_bill", col="sex", kde=True)

# %% [markdown]
# ### **ECDF Plot**
# Probability that a variable is less than or equal to x.
# Like: $P(X \le x)$

# %%
sns.ecdfplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Proportion'>

# %%
sns.kdeplot(tips["total_bill"])
sns.rugplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## **Relationship Plots**
# Relationship plots help answer questions like:
# * Does **X affect Y?**
# * Are two variables **positively correlated?**
# * Are they **negatively correlated?**
# * Is the relationship **linear or non-linear?**
#
# This is crucial when selecting **features for ML models.**

# %% [markdown]
# ### **Scatter Plot**
# A scatter plot shows the relationship between two numerical variables.
#
# Mathematically, we visualize pairs:
# $(x_1, y_1), (x_2, y_2), \dots, (x_n, y_n)$
# Each point represents one observation.
# Scatter plot helps us see:
# * correlation
# * clusters
# * outliers
# * patterns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)

plt.show()

# %% [markdown]
# ### **Adding Categories with Color**
# One of Seaborn's strengths is **visual grouping.**

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### **Adding More Dimensions**
# We can visualize **3 variables at once.**

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    hue="sex",
    size="size",
    data=tips
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### **Regression Plot (regplot)**
# This plot shows **relationship + regression line.**
# Regression equation:   $y = \beta_0 + \beta_1 x$
# Where:
# * $\beta_0$ = intercept
# * $\beta_1$ = slope

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### **lmplot (Advanced Regression Plot)**
# `lmplot()` is a figure-level function.

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
# With categories
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips)

# %% [markdown]
# ### **Pairplot ⭐ (Data Scientist Favorite)**
# This is one of the **most powerful EDA tools.**
#
# `pairplot()` automatically plots relationships between **all numerical variables.**

# %%
sns.pairplot(tips)

# %% [markdown]
# ### **Pairplot with Categories**

# %%
sns.pairplot(tips, hue="sex")

# %% [markdown]
# ## **Categorical Plots**
# A **categorical variable** is a variable that represents **groups or categories** instead of continuous numbers.
# | Category | Example Values |
# | -------- | -------------- |
# | Gender   | Male, Female   |
# | Day      | Mon, Tue, Wed  |
# | Class    | A, B, C        |
# | Product  | Phone, Laptop  |
#
# Seaborn provides specialized plots to analyze **numerical values across categories.**

# %% [markdown]
# ### **Count Plot**
# A **count plot** shows the **frequency of each category.**
# Mathematically:
# $$
# C = \{c_1, c_2, \dots, c_k\}
# $$

# %%
sns.countplot(x="day", data=tips)

plt.show()

# %%
# With grouping
sns.countplot(x="day", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ### **Bar Plot**
# A bar plot shows the average (mean) of a numerical variable for each category.
# Formula:
# $$
# \text{mean} = \frac{1}{n}\sum_{i=1}^{n} x_i
# $$

# %%
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# With grouping
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### **Box Plot ⭐**
# Very important in data science.
# A box plot visualizes distribution using quartiles.
# Five-number summary:
# $$
#  \text{min},\; Q_1,\; \text{median},\; Q_3,\; \text{max}
# $$
# Where
# * **Q1** = 25th percentile
# * **Median** = 50th percentile
# * **Q3** = 75th percentile
#
# Outliers are also shown.

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# With grouping
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### **Violin Plot**
# A **violin plot** is an advanced version of boxplot.
# It combines:
# * boxplot
# * KDE distribution
#
# Meaning:
# It shows data distribution shape.

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### **Strip Plot**
# Shows all individual data points.

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### **Swarm Plot**
# Improved version of strip plot (avoids overlapping points).

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## **Matrix Plots**
# Matrix plots visualize **relationships between many variables at once.**
# They are mainly used to analyze:
# * Correlation between features
# * Similarity between observations
# * Feature grouping
#
# The two main plots are:
# 1. Heatmap
# 2. Clustermap

# %% [markdown]
# ### **Correlation Matrix**
# Correlation measures the **strength of relationship between two variables.**
# The most common measure is **Pearson Correlation.**
# $$
# r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}
# {\sqrt{\sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}}
# $$
# Where:
# r = 1 → perfect positive correlation
# r = − 1 → perfect negative correlation
# r = 0 → no correlation
# Example correlation table:
# |   | A    | B   | C    |
# | - | ---- | --- | ---- |
# | A | 1    | 0.8 | -0.2 |
# | B | 0.8  | 1   | 0.3  |
# | C | -0.2 | 0.3 | 1    |

# %% [markdown]
# ### **Heatmap**
# A **heatmap** visualizes a matrix using color intensity.
# * Dark color → strong relationship
# * Light color → weak relationship

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

tips = sns.load_dataset("tips")

# Select only numeric columns for correlation calculation
numeric_tips = tips.select_dtypes(include=np.number)
corr = numeric_tips.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.show()

# %% [markdown]
# ### **Annotated Heatmap**
# Data scientists usually show actual correlation values.

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### **Changing Color Map**
# | Colormap | Use                      |
# | -------- | ------------------------ |
# | coolwarm | correlation analysis     |
# | viridis  | scientific visualization |
# | magma    | high contrast            |
# | rocket   | seaborn style            |

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### **Clustermap**
# A **clustermap** groups similar variables together.
# It performs **hierarchical clustering** automatically.
# Meaning:
# Variables with similar patterns will appear **closer together**.

# %%
sns.clustermap(corr)
