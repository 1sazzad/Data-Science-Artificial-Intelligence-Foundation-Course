# %% [markdown]
# <a href="https://colab.research.google.com/github/1sazzad/Data-Science-Artificial-Intelligence-Foundation-Course/blob/main/Matplotlib_Class_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# **What is Matplotlib?**
#
# -> Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# **Installation:**
#
#
# ```
# pip install matplotlib
# ```
# **Import:**
# ```
# import matplotlib
# ```
# **Checking Version:** The version string is stored under `__version__` attribute.
# ```
# print(matplotlib.__version__)
# ```

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ## Pyplot submodule and plt alias
# Most of the Matplotlib utilities lies under the `pyplot` submodule, and are usually imported under the `plt` alias.
# Using `plt` alias we can referred pyplot packages instead of using `matplotlib.pyplot`.
#
#
#
# ```
# # import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
# x = [2023, 2024, 2025, 2026]
# y = [15, 25, 30, 20]
#
# # x = np.array([2023, 2024, 2025, 2026])
# # y = np.array([15, 25, 30, 20])
# plt.plot(x, y) # The plot function is used to draw points(markers) in a diagram.
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np


# Say x is the year and y is the sels per year
# x = [2023, 2024, 2025, 2026]
# y = [15, 25, 30, 20]

x = np.array([2023, 2024, 2025, 2026])
y = np.array([15, 25, 30, 20])
plt.grid()
#plt.xticks(x)
plt.plot(x, y) # The plot function is used to draw points(markers) in a diagram.
plt.show()

# %% [markdown]
# ## Matplotlib Customization - marker
#
#
# ```
# from matplotlib.lines import lineStyles
# import matplotlib.pyplot as plt
# import numpy as np
# x = np.array([2023, 2024, 2025, 2026])
# y = np.array([15, 25, 30, 20])
# y2 = np.array([20, 44, 35, 30])
#
# plt.plot(x, y,
#           marker = ".",
#           markersize=20, # we can also use ms(mini markersize)
#           markerfacecolor = "#32a4a8",# short form is mfc
#           markeredgecolor = "#a83832",
#           linestyle = "dashed", # try dotted, dashdot, None, solid
#           linewidth = 2,
#           color = "#71a832"
#          )
# plt.plot(x, y2,
#           marker = ".",
#           markersize=20, # we can also use ms(mini markersize)
#           markerfacecolor = "#32a4a8",# short form is mfc
#           markeredgecolor = "#a83832",
#           linestyle = "dashed", # try dotted, dashdot, None, solid
#           linewidth = 2,
#           color = "#71a832"
#          )
# plt.show()
# ```

# %%
x = np.array([2023, 2024, 2025, 2026])
y = np.array([15, 25, 30, 20])
y2 = np.array([20, 44, 35, 30])
'''
y4, y5, y6 ....
'''

plt.plot(x, y,
         marker = "o",
         markersize=20, # we can also use ms(mini markersize)
         markerfacecolor = "#32a4a8",# short form is mfc
         markeredgecolor = "#a83832",
         linestyle = "solid", # try dotted, dashdot, None, solid
         linewidth = 2,
         color = "#71a832"
         )
plt.plot(x, y2,
          marker = "o",
         markersize=20, # we can also use ms(mini markersize)
         markerfacecolor = "#32a4a8",# short form is mfc
         markeredgecolor = "#a83832",
         linestyle = "solid", # try dotted, dashdot, None, solid
         linewidth = 2,
         color = "#71a832"
         )

plt.show()

# %% [markdown]
# ## **Application** of `**dict_name`
#
# The `**` used to unpack the dictionary
#
# if $D = \{ k_1 : v_1, k_2 : v_2, \dots, k_n : v_n \}$
#
# $f(**D) = f(k_1 = v_1, k_2 = v_2, \dots, k_n = v_n)$
#
# **Conceptual Diagram:**
#
#
#
# ```
# line_style (dict)
#         ↓
# ** unpacking
#         ↓
# converted to keyword arguments
#         ↓
# received in plot() as kwargs
#         ↓
# Matplotlib applies styling
# ```
#
#
#
# **Why Use Dictionary Instead of Writing Directly?**

# %%
x = np.array([2023, 2024, 2025, 2026])
y = np.array([15, 25, 30, 20])
y2 = np.array([20, 44, 35, 30])
'''
y4, y5, y6 ....
'''

dict_Name = {
    "marker" : "o",
    "markersize": 20, # we can also use ms(mini markersize)
    "markerfacecolor" : "#32a4a8",# short form is mfc
    "markeredgecolor" : "#a83832",
    "linestyle" : "solid", # try dotted, dashdot, None, solid
    "linewidth" : 2,
    "color" : "#71a832"
}

plt.plot(x, y, **dict_Name)
plt.plot(x, y2, **dict_Name )

plt.show()

# %% [markdown]
# ### Let's do something funny

# %%
import matplotlib.pyplot as plt
import numpy as np

H = 10
W = 6
gap = 4

x_points = []
y_points = []

for y in range(H):
    for x in range(3*W + 2*gap):

        # --- LETTER I ---
        if x < W:
            if y == 0 or y == H-1 or x == W//2:
                x_points.append(x)
                y_points.append(H - y)

        # --- LETTER S ---
        elif W + gap <= x < 2*W + gap:
            xs = x - (W + gap)

            if (
                y == 0 or
                y == H//2 or
                y == H-1 or
                (y < H//2 and xs == 0) or
                (y > H//2 and xs == W-1)
            ):
                x_points.append(x)
                y_points.append(H - y)

        # --- LETTER T ---
        elif x >= 2*W + 2*gap:
            xt = x - (2*W + 2*gap)

            if y == 0 or xt == W//2:
                x_points.append(x)
                y_points.append(H - y)

plt.figure(figsize=(8,4))
plt.scatter(x_points, y_points)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis('off')
plt.title("IST plotted mathematically")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-1.5, 1.5, 0.01)
y = np.arange(-1.5, 1.5, 0.01)
X, Y = np.meshgrid(x, y)

F = (X**2 + Y**2 - 1)**3 - X**2 * Y**3
crack = (X > 0) & (Y < 0.5*X) & (Y > 0.5*X - 0.2)

mask = (F <= 0) & (~crack)

plt.figure(figsize=(6,6))
plt.scatter(X[mask], Y[mask], c='#E24B5A')
plt.gca().set_aspect('equal')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Grid Lines
#
# **Internal Architecture Diagram**
# ```
# Figure
#   └── Axes
#         ├── XAxis
#         │     ├── MajorTicks
#         │     ├── MinorTicks
#         │     └── GridLines
#         ├── YAxis
#         │     ├── MajorTicks
#         │     ├── MinorTicks
#         │     └── GridLines
#         └── Data Lines
# ```
#
#
#
# ```
# x = [1, 2, 3, 4, 5]
# y = [5, 10, 15, 20, 25]
#
# plt.grid(
#     axis = "both",
#     linewidth = 1,
#     color = "green",
#     linestyle = "--" # dashed, dotted, dashdot
# )
# plt.minorticks_on()
# plt.plot(x,y)
# plt.show()
# ```

# %%
x = [1, 2, 3, 4, 5]
y = [5, 10, 15, 20, 25]

plt.grid(
    axis = "both",
    linewidth = 1,
    color = "green",
    linestyle = "--" # dashed, dotted, dashdot
)
plt.minorticks_on()
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Labels
# ```
# Figure
# │
# └── Axes
#     │
#     └── Axis (X-axis, Y-axis)
#         │
#         └── Text (labels, ticks, title)
# ```
#
#
# ```
# from matplotlib.lines import lineStyles
# import matplotlib.pyplot as plt
# import numpy as np
# x = np.array([2023, 2024, 2025, 2026])
# y1 = np.array([15, 25, 30, 20])
# y2 = np.array([20, 44, 35, 30])
# y3 = np.array([10, 24, 30, 10])
#
# label_format = dict(
#     fontsize = 12,
#     family = "serif",
#     fontweight = "bold",
#     color = "#2d4cfc"
# )
# plt.title("Class Size", **label_format)
# plt.xlabel("Year", **label_format)
# plt.ylabel("Student", **label_format)
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.plot(x, y3)
# plt.xticks(x)
# plt.show()
# ```
#
# `xticks()` A list or array of positions where you want the ticks to appear on the x-axis

# %%
x = np.array([2023, 2024, 2025, 2026])
y1 = np.array([15, 25, 30, 20])
y2 = np.array([20, 44, 35, 30])
y3 = np.array([10, 24, 30, 10])

label_format = dict(
    fontsize = 12,
    family = "serif",
    fontweight = "bold",
    color = "#2d4cfc"
)
plt.title("Class Size", **label_format)
plt.xlabel("Year", **label_format)
plt.ylabel("Student", **label_format)

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.xticks(x) #
plt.grid()
plt.show()

# %% [markdown]
# ## Bar Charts
# Bar Charts = Compare categories of data by representing each category with a bar
#
# ```
# Figure
#   └── Axes
#         ├── Rectangle (bar1)
#         ├── Rectangle (bar2)
#         ├── Rectangle (bar3)
#         └── ...
# ```
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# years = np.array([2023, 2024, 2025, 2026])
# sales = np.array([15, 25, 30, 20])
#
# plt.bar(years, sales)
# # plt.barh(years,sales)
#
# plt.xlabel("Year")
# plt.ylabel("Sales")
# plt.title("Annual Sales")
# plt.xticks(years)
#
# plt.show()
# ```

# %%
years = np.array([2023, 2024, 2025, 2026])
sales = np.array([15, 25, 30, 20])

plt.bar(years, sales)
# plt.barh(years,sales)

plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Annual Sales")
plt.xticks(years)
#plt.grid()

plt.show()

# %% [markdown]
# ## Pie Chart
# ```
# Figure
#   └── Axes
#         ├── Wedge (slice 1)
#         ├── Wedge (slice 2)
#         ├── Wedge (slice 3)
#         └── Text (labels)
# ```
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# categories = ["Freshmen", "Sophomores", "Juniors", "Seniors"]
# values = np.array([300, 250, 275, 225])
# colors = ["red", "Yellow", "Green", "Blue"]
#
# plt.pie(values, labels=categories,
#                 autopct = "%1.2f%%",
#                 colors = colors,
#                 explode = [0,0,0,0.1])
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ["Freshmen", "Sophomores", "Juniors", "Seniors"]
values = np.array([300, 250, 275, 225])
colors = ["red", "Yellow", "Green", "Blue"]

plt.pie(values, labels=categories,
                autopct = "%1.2f%%",
                colors = colors,
                explode = [0,0,0,0.1]
        )


plt.show()

# %% [markdown]
# ## Scatter graph
# Scatter Graph = Shows the relationship between two variables helps to identify a correlation (+, -, none).
# **Example:** Study hours vs. Test Scores
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.array([0, 1, 1, 2, 3, 4, 5, 6, 7, 7, 8]) # hours studied
# y = np.array([55, 60, 65, 62, 68, 70, 75, 78, 82, 85, 87]) # Grades
#
# x1 = np.array([1, 1, 2, 3, 3, 4, 6, 7, 8, 8, 9]) # hours studied
# y1 = np.array([60, 65, 70, 71, 75, 78, 80, 82, 85, 85, 87]) # Grades
#
#
# plt.scatter(x, y,
#             color = "red",
#             s = 100,
#             label = "Class A"
#             )
# plt.scatter(x1, y1,
#             color = "green",
#             s = 100,
#             label = "Class B"
#             )
#
# plt.title("Test Scores")
# plt.xlabel("Hours Studied")
# plt.ylabel("Grades")
# plt.legend()
#
# plt.show()
# ```

# %%
x = np.array([0, 1, 1, 2, 3, 4, 5, 6, 7, 7, 8]) # hours studied
y = np.array([55, 60, 65, 62, 68, 70, 75, 78, 82, 85, 87]) # Grades

x1 = np.array([1, 1, 2, 3, 3, 4, 6, 7, 8, 8, 9]) # hours studied
y1 = np.array([60, 65, 70, 71, 75, 78, 80, 82, 85, 85, 87]) # Grades


plt.scatter(x, y,
            color = "red",
            s = 100,
            label = "Class A"
            )
plt.scatter(x1, y1,
            color = "green",
            s = 100,
            label = "Class B"
            )

plt.title("Test Scores")
plt.xlabel("Hours Studied")
plt.ylabel("Grades")
plt.legend()

plt.show()

# %% [markdown]
# ## Histograms
# Histogram = A visual representation of the distribution of quantitative data. They group values into bins (intervals) and count how many fall in each range.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(100)

# fig, ax = plt.subplots()

plt.hist(data, bins=10)

plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
print(data)
plt.show()
# Out:
# [-0.7168944  -0.03173869  1.04812221  1.02186225  0.69486318  0.64571584
#  -1.18823156  0.53681959  0.33191074 -0.6135947  -1.12891957  0.43732784
#  -0.0780789   1.13991807  1.90768545  2.54827587  0.72080515  2.11356289
#   0.3863278  -0.12125951  0.48626213  0.67795187  0.11571661  1.70794408
#  -0.58495838 -0.33591898  0.3587689  -1.60995234 -1.02840901 -0.42572891
#  -1.3362347   0.95443997 -0.8787272  -0.89373281 -0.81372159  0.2523424
#   0.30237877  0.290663    0.22274928 -0.02565729  1.46584043 -0.61310879
#  -0.07392824  0.63103873 -0.94946721 -1.16048749 -0.08634931 -0.6156391
#  -2.05368838  1.31907882  0.72869954 -1.22847679  1.25832185  0.66512931
#   0.2527053   0.16698832  1.94255268 -0.70788247  0.40008789  0.4750273
#  -0.09966674  0.09116535  0.15770956 -1.15532555 -0.64805307 -0.78142158
#   0.6210662   1.35645605  0.59155039 -0.8977519  -1.9704555   0.08359966
#  -0.28041402 -0.22650305  0.07862496  1.55826981  2.67661067 -0.38919744
# ...

# %% [markdown]
# ## Sub Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create simple arrays
x = np.array([1, 2, 3, 4, 5])

y1 = np.array([2, 4, 6, 8, 10])
y2 = np.array([1, 3, 5, 7, 9])
y3 = np.array([5, 3, 4, 2, 1])
y4 = np.array([10, 8, 6, 4, 2])

# Create 2x2 subplots
fig, axs = plt.subplots(2, 2, figsize=(8, 6))

axs[0, 0].plot(x, y1)
axs[0, 0].set_title("Array 1")

axs[0, 1].plot(x, y2)
axs[0, 1].set_title("Array 2")

axs[1, 0].plot(x, y3)
axs[1, 0].set_title("Array 3")

axs[1, 1].plot(x, y4)
axs[1, 1].set_title("Array 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# **Goal:** Visualize marks of 5 students in 4 subjects.
#
# **Requirement**
#
#
# 1.   bar()
# 2.   subplot()
# 3.  legend()
#
# **Data Example**
#
# ```
# students = ["A", "B", "C", "D", "E"]
#
# math = np.array([80, 75, 90, 85, 70])
# physics = np.array([78, 72, 88, 80, 68])
# chemistry = np.array([85, 70, 92, 88, 75])
# english = np.array([90, 85, 95, 89, 80])
# ```
# **What you do must:**
# 1. Creat 2x2 subplots
# 2. Each subplot &rarr; one subject
# 3. Use bar chart
# 4. Add titles, labels
# 5. Add subtitles
#
# **Skills you will Practice:**
# * Subplots
# * Bar Chart
# * Layout control
# * Axis labeling

# %%
import matplotlib.pyplot as plt
import numpy as np

students = ["A", "B", "C", "D", "E"]

math = np.array([80, 75, 90, 85, 70])
physics = np.array([78, 72, 88, 80, 68])
chemistry = np.array([85, 70, 92, 88, 75])
english = np.array([90, 85, 95, 89, 80])


fig, axs = plt.subplots(2, 2, figsize=(8, 8))

axs[0, 0].bar(students, math, label="Math Marks")
axs[0, 0].set_title("Math")
axs[0, 0].set_xlabel("Students")
axs[0, 0].set_ylabel("Marks")
axs[0, 0].legend()

axs[0, 1].bar(students, physics, label="Physics Marks")
axs[0, 1].set_title("Physics")
axs[0, 1].set_xlabel("Students")
axs[0, 1].set_ylabel("Marks")
axs[0, 1].legend()

axs[1, 0].bar(students, chemistry, label="Chemistry Marks")
axs[1, 0].set_title("Chemistry")
axs[1, 0].set_xlabel("Students")
axs[1, 0].set_ylabel("Marks")
axs[1, 0].legend()

axs[1, 1].bar(students, english, label="English Marks")
axs[1, 1].set_title("English")
axs[1, 1].set_xlabel("Students")
axs[1, 1].set_ylabel("Marks")
axs[1, 1].legend()

plt.suptitle("Marks of 5 Students in 4 Subjects")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
students = ["A", "B", "C", "D", "E"]

math = np.array([80, 75, 90, 85, 70])
physics = np.array([78, 72, 88, 80, 68])
chemistry = np.array([85, 70, 92, 88, 75])
english = np.array([90, 85, 95, 89, 80])

fig, axs = plt.subplots(2, 2, figsize=(8, 6))

axs[0, 0].bar(students, math)
axs[0, 0].set_title("Math")
axs[0, 0].set_xlabel("Students")
axs[0, 0].set_ylabel("Marks")

axs[0, 1].bar(students, physics)
axs[0, 1].bar(students, physics,label="Physics marks")
axs[0, 1].set_title("Physics")
axs[0, 1].set_xlabel("Students")
axs[0, 1].set_ylabel("Marks")
axs[0,1].legend()

axs[1, 0].bar(students, chemistry)
axs[1, 0].bar(students, chemistry, label="Chemistry marks")
axs[1, 0].set_title("Chemistry")
axs[1, 0].set_xlabel("Students")
axs[1, 0].set_ylabel("Marks")
axs[1,0].legend()

axs[1, 1].bar(students, english)
axs[1, 1].bar(students, english, label="English marks")
axs[1, 1].set_title("English")
axs[1, 1].set_xlabel("Students")
axs[1, 1].set_ylabel("Marks")

plt.tight_layout()
plt.show()
